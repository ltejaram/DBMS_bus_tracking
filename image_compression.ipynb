# %% [markdown]
# <a href="https://colab.research.google.com/github/ltejaram/DBMS_bus_tracking/blob/main/image_compression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil

# Define the paths for the zip file in Google Drive and the destination in Colab
google_drive_zip_path = "/content/drive/My Drive/vavqe2-Images.zip"
colab_destination_path = "/content/"

# Copy the zip file from Google Drive to Colab
shutil.copy(google_drive_zip_path, colab_destination_path)
# Out:
# '/content/vavqe2-Images.zip'

# %%
# !unzip vavqe2-Images.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: VQ-VAE-2-Images/1024/frontal/original/1261.png
#   inflating: VQ-VAE-2-Images/1024/frontal/original/1262.png
#   inflating: VQ-VAE-2-Images/1024/frontal/original/1263.png
#   inflating: VQ-VAE-2-Images/1024/frontal/original/1264.png
#   inflating: VQ-VAE-2-Images/1024/frontal/original/1265.png
#   inflating: VQ-VAE-2-Images/1024/frontal/original/1266.png
#   inflating: VQ-VAE-2-Images/1024/frontal/original/1267.png
#   inflating: VQ-VAE-2-Images/1024/frontal/original/1268.png
#   inflating: VQ-VAE-2-Images/1024/frontal/original/1269.png
#   inflating: VQ-VAE-2-Images/1024/frontal/original/1270.png
#   inflating: VQ-VAE-2-Images/1024/frontal/original/1271.png
#   inflating: VQ-VAE-2-Images/1024/frontal/original/1272.png
#   inflating: VQ-VAE-2-Images/1024/frontal/original/1273.png
#   inflating: VQ-VAE-2-Images/1024/frontal/original/1274.png
#   inflating: VQ-VAE-2-Images/1024/frontal/original/1275.png
# ...

# %%
# !git clone https://github.com/aisinai/vqvae2.git
# Out:
# Cloning into 'vqvae2'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 110 (delta 65), reused 74 (delta 29), pack-reused 0
# Receiving objects: 100% (110/110), 8.59 MiB | 16.79 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
#!pip install torch torchvision h5py numpy tqdm matplotlib scikit-learn

# !python vqvae2/create_hdf5.py
# Out:
# this is reader ['path,png,view,No Finding,Enlarged Cardiomediastinum,Cardiomegaly,Airspace Opacity,Lung Lesion,Edema,Consolidation,Pneumonia,Atelectasis,Pneumothorax,Pleural Effusion,Pleural Other,Fracture,Support Devices'] mimic
# ...

# %%
# !python vqvae2/train_vqvae.py --data_path="./HDF5_datasets" --save_path="./HDF5_datasets"
# Out:
# size: 256
# n_epochs: 9
# lr: 0.0003
# first_stride: 4
# second_stride: 2
# embed_dim: 64
# data_path: ./HDF5_datasets
# dataset: mimic
# view: frontal
# save_path: ./HDF5_datasets
# train_run: 0
#   0% 0/13 [00:00<?, ?it/s]/content/vqvae2/networks.py:54: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1519.)
#   self.cluster_size.data.mul_(self.decay).add_(
# phase: train; epoch: 1; total_loss: 1.67044; latent: 2.19440; mse: 1.12184; lr: 0.00030: 100% 13/13 [00:20<00:00,  1.61s/it]
# /content/vqvae2/utilities.py:161: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax1.axis(xmin=1, xmax=latest_epoch)
# ...

# %%
# !pip install pytorch_memlab
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pytorch_memlab: filename=pytorch_memlab-0.3.0-py3-none-any.whl size=22524 sha256=7ff7daa4192eb8e68c64a1053f1dc9b9241a847814387014bb998120d91ccba0
#   Stored in directory: /root/.cache/pip/wheels/c5/c2/39/6ed79acd1330a5070143a62ac66c174a57e4786ccd0a23da1d
# ...
#   Created wheel for calmsize: filename=calmsize-0.1.3-py3-none-any.whl size=2869 sha256=9ee7dba846d01511cfa0545d873661fe7889b89f2a2c3e7375fc9c77466f9125
#   Stored in directory: /root/.cache/pip/wheels/5c/b5/ad/4ec2d714dc114d33dadc848a8874b2c0b33fcf323addc75cd4
# Successfully built pytorch_memlab calmsize
# ...

# %%
# !python ./vqvae2/create_images.py --data_path="./HDF5_datasets" --size=256 --save_path="./HDF5_datasets"
# Out:
# Model A:: 100% 440/440 [01:11<00:00,  6.19it/s]

# %%
# !python ./vqvae2/create_vqvae2_output_hdf5.py --data_path="./HDF5_datasets" --save_path="./HDF5_datasets"
# Out:
# Namespace(size=256, batch_size=4, first_stride=4, second_stride=2, embed_dim=64, data_path='./HDF5_datasets', dataset='mimic', view='frontal', save_path='./HDF5_datasets', train_run='0', vqvae_file='vqvae_040.pt')
# phase: train: 100% 220/220 [00:31<00:00,  7.00it/s]
# phase: valid: 100% 220/220 [00:32<00:00,  6.82it/s]
